# %%
import requests

path = "<PATH_TO_IMAGE_FILE>"
url ="http://localhost:8001/detect/yolo/ARTS" # if you
# print(requests.get(url).json())
data = {"file": f"{path}","classname":"stop"}
response = requests.post(url, json=data)
print(response)
response.json()
result = response.json()

result
# Out:
# <Response [200]>
# 0.9999949932098389

# %%
import requests

url = "http://localhost:8001/detect/fasterrcnn/mapillary"
# print(requests.get(url).json())
data = {"file": f"{path}","classname":"stop"}
response = requests.post(url, json=data)

# print(response)
result = response.json()

result
# Out:
# 0.9999263286590576
